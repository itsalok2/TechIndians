# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.preprocessing import StandardScaler 
import xgboost as xgb 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
x = pd.read_csv('X_features.csv')
y_reaction = pd.read_csv('y_reaction.csv')
y_severity = pd.read_csv('y_severity.csv')

# %%
y_reaction.shape,y_severity.shape,x.shape
# Out:
# ((1260833, 1), (1260833, 1), (1260833, 12))

# %%
df_model = x.copy()
df_model['y_reaction'] = y_reaction.values
df_model['y_severity']= y_severity.values

# %%
X_fea= df_model.drop(['y_reaction','y_severity'],axis = 1)
y_reaction_target = df_model['y_reaction'] 
y_severity_target = df_model['y_severity']-1

# %%
# Y_Reaction (Reaction Type Prediction)
# What it predicts: Which specific adverse reaction will occur (e.g., "Nausea", "Headache", "Rash")

# Intuition/Use Case:

# Early warning system: "If patient takes Drug X for Condition Y, they're likely to experience Reaction Z"
# Personalized medicine: Predict which specific side effects a patient might experience
# Drug development: Identify common reaction patterns for new drugs
# Clinical decision support: Help doctors anticipate and prepare for specific adverse events
# Example: Patient on METFORMIN for diabetes → Predict they'll likely experience "Gastrointestinal discomfort" rather than "Liver damage"

# Y_Severity (Severity Level Prediction)
# What it predicts: How serious the adverse event will be (1=Other, 3=Hospitalization, 6=Death)

# Intuition/Use Case:

# Risk stratification: Identify high-risk patients who need closer monitoring
# Resource allocation: Predict which cases need immediate intervention
# Drug safety: Flag drug combinations that lead to severe outcomes
# Regulatory decisions: Inform drug approval/withdrawal decisions
# Example: Same patient on METFORMIN → Predict severity level 1 (mild, outpatient management) vs level 6 (life-threatening)

# Why Both?
# They answer different clinical questions:
# Reaction (WHAT): "What will happen to the patient?"
# Severity (HOW BAD): "How serious will it be?"
# Real-world scenario:

# Drug A → 90% chance of nausea (annoying but manageable)
# Drug B → 10% chance of liver failure (rare but deadly)

# %%
# Split data (70% train, 15% validation, 15% test)
X_train, X_temp, y_reaction_train, y_reaction_temp = train_test_split(
    X_fea, y_reaction_target, test_size=0.3, random_state=42, stratify=y_reaction_target
)

X_val, X_test, y_reaction_val, y_reaction_test = train_test_split(
    X_temp, y_reaction_temp, test_size=0.5, random_state=42, stratify=y_reaction_temp
)

# Same split for severity
_, _, y_severity_train, y_severity_temp = train_test_split(
    X_fea, y_severity_target, test_size=0.3, random_state=42, stratify=y_severity_target
)

_, _, y_severity_val, y_severity_test = train_test_split(
    X_temp, y_severity_temp, test_size=0.5, random_state=42, stratify=y_severity_temp
)

# %%
print(f"\nTrain set: {X_train.shape}")
print(f"Validation set: {X_val.shape}")
print(f"Test set: {X_test.shape}")
# Out:
# Train set: (882583, 12)
# Validation set: (189125, 12)
# Test set: (189125, 12)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### reaction classifier(not needed)

# %%
xgb_reaction = xgb.XGBClassifier(
    n_estimators=150,
    max_depth=7,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    eval_metric='mlogloss'
)

xgb_reaction.fit(
    X_train_scaled, y_reaction_train,
    eval_set=[(X_val_scaled, y_reaction_val)],
    verbose=True
)

# %% [markdown]
# ### severity classifier (important)

# %%
xgb_severity = xgb.XGBClassifier(
    n_estimators=400,
    max_depth=10,
    learning_rate=0.1436348834661225,
    subsample=0.6109356180111788,
    colsample_bytree=0.9448531875640296,
    min_child_weight=7,
    gamma=4.260249158096812,

    # required / good practice
    objective="multi:softprob",
    num_class=6,
    eval_metric="mlogloss",
    random_state=42
)

# Train the model
xgb_severity.fit(
    X_train_scaled, y_severity_train,
    eval_set=[(X_val_scaled, y_severity_val)],
    verbose=True
)
# Out:
# [0]	validation_0-mlogloss:1.20224
# [1]	validation_0-mlogloss:1.10842
# [2]	validation_0-mlogloss:1.03334
# [3]	validation_0-mlogloss:0.97230
# [4]	validation_0-mlogloss:0.92226
# [5]	validation_0-mlogloss:0.88086
# [6]	validation_0-mlogloss:0.84649
# [7]	validation_0-mlogloss:0.81780
# [8]	validation_0-mlogloss:0.79376
# [9]	validation_0-mlogloss:0.77355
# [10]	validation_0-mlogloss:0.75650
# [11]	validation_0-mlogloss:0.74205
# [12]	validation_0-mlogloss:0.72979
# [13]	validation_0-mlogloss:0.71932
# [14]	validation_0-mlogloss:0.71036
# [15]	validation_0-mlogloss:0.70265
# [16]	validation_0-mlogloss:0.69599
# [17]	validation_0-mlogloss:0.69021
# [18]	validation_0-mlogloss:0.68516
# [19]	validation_0-mlogloss:0.68074
# [20]	validation_0-mlogloss:0.67685
# [21]	validation_0-mlogloss:0.67343
# [22]	validation_0-mlogloss:0.67038
# [23]	validation_0-mlogloss:0.66768
# [24]	validation_0-mlogloss:0.66526
# [25]	validation_0-mlogloss:0.66311
# [26]	validation_0-mlogloss:0.66117
# [27]	validation_0-mlogloss:0.65943
# [28]	validation_0-mlogloss:0.65786
# [29]	validation_0-mlogloss:0.65644
# [30]	validation_0-mlogloss:0.65517
# [31]	validation_0-mlogloss:0.65402
# [32]	validation_0-mlogloss:0.65299
# [33]	validation_0-mlogloss:0.65205
# [34]	validation_0-mlogloss:0.65119
# [35]	validation_0-mlogloss:0.65043
# [36]	validation_0-mlogloss:0.64973
# [37]	validation_0-mlogloss:0.64909
# [38]	validation_0-mlogloss:0.64852
# [39]	validation_0-mlogloss:0.64800
# [40]	validation_0-mlogloss:0.64753
# [41]	validation_0-mlogloss:0.64710
# [42]	validation_0-mlogloss:0.64670
# [43]	validation_0-mlogloss:0.64635
# [44]	validation_0-mlogloss:0.64603
# [45]	validation_0-mlogloss:0.64574
# [46]	validation_0-mlogloss:0.64547
# [47]	validation_0-mlogloss:0.64523
# [48]	validation_0-mlogloss:0.64500
# [49]	validation_0-mlogloss:0.64480
# [50]	validation_0-mlogloss:0.64462
# [51]	validation_0-mlogloss:0.64444
# [52]	validation_0-mlogloss:0.64429
# [53]	validation_0-mlogloss:0.64415
# [54]	validation_0-mlogloss:0.64402
# [55]	validation_0-mlogloss:0.64390
# [56]	validation_0-mlogloss:0.64379
# [57]	validation_0-mlogloss:0.64369
# [58]	validation_0-mlogloss:0.64360
# [59]	validation_0-mlogloss:0.64352
# [60]	validation_0-mlogloss:0.64344
# [61]	validation_0-mlogloss:0.64337
# [62]	validation_0-mlogloss:0.64330
# [63]	validation_0-mlogloss:0.64324
# [64]	validation_0-mlogloss:0.64319
# [65]	validation_0-mlogloss:0.64314
# [66]	validation_0-mlogloss:0.64309
# [67]	validation_0-mlogloss:0.64305
# [68]	validation_0-mlogloss:0.64301
# [69]	validation_0-mlogloss:0.64297
# [70]	validation_0-mlogloss:0.64294
# [71]	validation_0-mlogloss:0.64291
# [72]	validation_0-mlogloss:0.64288
# [73]	validation_0-mlogloss:0.64285
# [74]	validation_0-mlogloss:0.64283
# [75]	validation_0-mlogloss:0.64281
# [76]	validation_0-mlogloss:0.64278
# [77]	validation_0-mlogloss:0.64277
# [78]	validation_0-mlogloss:0.64275
# [79]	validation_0-mlogloss:0.64273
# [80]	validation_0-mlogloss:0.64272
# [81]	validation_0-mlogloss:0.64271
# [82]	validation_0-mlogloss:0.64269
# [83]	validation_0-mlogloss:0.64268
# [84]	validation_0-mlogloss:0.64267
# [85]	validation_0-mlogloss:0.64266
# [86]	validation_0-mlogloss:0.64265
# [87]	validation_0-mlogloss:0.64265
# [88]	validation_0-mlogloss:0.64264
# [89]	validation_0-mlogloss:0.64263
# [90]	validation_0-mlogloss:0.64263
# [91]	validation_0-mlogloss:0.64262
# [92]	validation_0-mlogloss:0.64261
# [93]	validation_0-mlogloss:0.64261
# [94]	validation_0-mlogloss:0.64261
# [95]	validation_0-mlogloss:0.64260
# [96]	validation_0-mlogloss:0.64260
# [97]	validation_0-mlogloss:0.64259
# [98]	validation_0-mlogloss:0.64259
# [99]	validation_0-mlogloss:0.64259
# [100]	validation_0-mlogloss:0.64259
# [101]	validation_0-mlogloss:0.64259
# [102]	validation_0-mlogloss:0.64258
# [103]	validation_0-mlogloss:0.64258
# [104]	validation_0-mlogloss:0.64258
# [105]	validation_0-mlogloss:0.64258
# [106]	validation_0-mlogloss:0.64258
# [107]	validation_0-mlogloss:0.64258
# [108]	validation_0-mlogloss:0.64258
# [109]	validation_0-mlogloss:0.64258
# [110]	validation_0-mlogloss:0.64258
# [111]	validation_0-mlogloss:0.64258
# [112]	validation_0-mlogloss:0.64258
# [113]	validation_0-mlogloss:0.64257
# [114]	validation_0-mlogloss:0.64258
# [115]	validation_0-mlogloss:0.64258
# [116]	validation_0-mlogloss:0.64258
# [117]	validation_0-mlogloss:0.64257
# [118]	validation_0-mlogloss:0.64257
# [119]	validation_0-mlogloss:0.64257
# [120]	validation_0-mlogloss:0.64257
# [121]	validation_0-mlogloss:0.64257
# [122]	validation_0-mlogloss:0.64257
# [123]	validation_0-mlogloss:0.64257
# [124]	validation_0-mlogloss:0.64257
# [125]	validation_0-mlogloss:0.64257
# [126]	validation_0-mlogloss:0.64257
# [127]	validation_0-mlogloss:0.64257
# [128]	validation_0-mlogloss:0.64257
# [129]	validation_0-mlogloss:0.64257
# [130]	validation_0-mlogloss:0.64257
# [131]	validation_0-mlogloss:0.64257
# [132]	validation_0-mlogloss:0.64257
# [133]	validation_0-mlogloss:0.64257
# [134]	validation_0-mlogloss:0.64257
# [135]	validation_0-mlogloss:0.64257
# [136]	validation_0-mlogloss:0.64257
# [137]	validation_0-mlogloss:0.64257
# [138]	validation_0-mlogloss:0.64257
# [139]	validation_0-mlogloss:0.64257
# [140]	validation_0-mlogloss:0.64257
# [141]	validation_0-mlogloss:0.64257
# [142]	validation_0-mlogloss:0.64257
# [143]	validation_0-mlogloss:0.64257
# [144]	validation_0-mlogloss:0.64257
# [145]	validation_0-mlogloss:0.64257
# [146]	validation_0-mlogloss:0.64257
# [147]	validation_0-mlogloss:0.64257
# [148]	validation_0-mlogloss:0.64257
# [149]	validation_0-mlogloss:0.64257
# [150]	validation_0-mlogloss:0.64257
# [151]	validation_0-mlogloss:0.64257
# [152]	validation_0-mlogloss:0.64257
# [153]	validation_0-mlogloss:0.64257
# [154]	validation_0-mlogloss:0.64257
# [155]	validation_0-mlogloss:0.64257
# [156]	validation_0-mlogloss:0.64257
# [157]	validation_0-mlogloss:0.64257
# [158]	validation_0-mlogloss:0.64257
# [159]	validation_0-mlogloss:0.64257
# [160]	validation_0-mlogloss:0.64257
# [161]	validation_0-mlogloss:0.64257
# [162]	validation_0-mlogloss:0.64257
# [163]	validation_0-mlogloss:0.64257
# [164]	validation_0-mlogloss:0.64257
# [165]	validation_0-mlogloss:0.64257
# [166]	validation_0-mlogloss:0.64257
# [167]	validation_0-mlogloss:0.64257
# [168]	validation_0-mlogloss:0.64257
# [169]	validation_0-mlogloss:0.64257
# [170]	validation_0-mlogloss:0.64258
# [171]	validation_0-mlogloss:0.64258
# [172]	validation_0-mlogloss:0.64258
# [173]	validation_0-mlogloss:0.64258
# [174]	validation_0-mlogloss:0.64258
# [175]	validation_0-mlogloss:0.64258
# [176]	validation_0-mlogloss:0.64258
# [177]	validation_0-mlogloss:0.64258
# [178]	validation_0-mlogloss:0.64258
# [179]	validation_0-mlogloss:0.64258
# [180]	validation_0-mlogloss:0.64258
# [181]	validation_0-mlogloss:0.64258
# [182]	validation_0-mlogloss:0.64258
# [183]	validation_0-mlogloss:0.64258
# [184]	validation_0-mlogloss:0.64258
# [185]	validation_0-mlogloss:0.64258
# [186]	validation_0-mlogloss:0.64258
# [187]	validation_0-mlogloss:0.64258
# [188]	validation_0-mlogloss:0.64258
# [189]	validation_0-mlogloss:0.64258
# [190]	validation_0-mlogloss:0.64258
# [191]	validation_0-mlogloss:0.64257
# [192]	validation_0-mlogloss:0.64257
# [193]	validation_0-mlogloss:0.64257
# [194]	validation_0-mlogloss:0.64257
# [195]	validation_0-mlogloss:0.64257
# [196]	validation_0-mlogloss:0.64257
# [197]	validation_0-mlogloss:0.64257
# [198]	validation_0-mlogloss:0.64257
# [199]	validation_0-mlogloss:0.64257
# [200]	validation_0-mlogloss:0.64257
# [201]	validation_0-mlogloss:0.64257
# [202]	validation_0-mlogloss:0.64257
# [203]	validation_0-mlogloss:0.64257
# [204]	validation_0-mlogloss:0.64257
# [205]	validation_0-mlogloss:0.64258
# [206]	validation_0-mlogloss:0.64257
# [207]	validation_0-mlogloss:0.64258
# [208]	validation_0-mlogloss:0.64258
# [209]	validation_0-mlogloss:0.64258
# [210]	validation_0-mlogloss:0.64258
# [211]	validation_0-mlogloss:0.64258
# [212]	validation_0-mlogloss:0.64258
# [213]	validation_0-mlogloss:0.64258
# [214]	validation_0-mlogloss:0.64257
# [215]	validation_0-mlogloss:0.64257
# [216]	validation_0-mlogloss:0.64257
# [217]	validation_0-mlogloss:0.64257
# [218]	validation_0-mlogloss:0.64257
# [219]	validation_0-mlogloss:0.64257
# [220]	validation_0-mlogloss:0.64257
# [221]	validation_0-mlogloss:0.64257
# [222]	validation_0-mlogloss:0.64257
# [223]	validation_0-mlogloss:0.64257
# [224]	validation_0-mlogloss:0.64257
# [225]	validation_0-mlogloss:0.64257
# [226]	validation_0-mlogloss:0.64257
# [227]	validation_0-mlogloss:0.64257
# [228]	validation_0-mlogloss:0.64258
# [229]	validation_0-mlogloss:0.64258
# [230]	validation_0-mlogloss:0.64258
# [231]	validation_0-mlogloss:0.64258
# [232]	validation_0-mlogloss:0.64258
# [233]	validation_0-mlogloss:0.64258
# [234]	validation_0-mlogloss:0.64258
# [235]	validation_0-mlogloss:0.64258
# [236]	validation_0-mlogloss:0.64258
# [237]	validation_0-mlogloss:0.64258
# [238]	validation_0-mlogloss:0.64258
# [239]	validation_0-mlogloss:0.64258
# [240]	validation_0-mlogloss:0.64258
# [241]	validation_0-mlogloss:0.64258
# [242]	validation_0-mlogloss:0.64258
# [243]	validation_0-mlogloss:0.64258
# [244]	validation_0-mlogloss:0.64258
# [245]	validation_0-mlogloss:0.64258
# [246]	validation_0-mlogloss:0.64258
# [247]	validation_0-mlogloss:0.64258
# [248]	validation_0-mlogloss:0.64258
# [249]	validation_0-mlogloss:0.64257
# [250]	validation_0-mlogloss:0.64257
# [251]	validation_0-mlogloss:0.64257
# [252]	validation_0-mlogloss:0.64257
# [253]	validation_0-mlogloss:0.64257
# [254]	validation_0-mlogloss:0.64257
# [255]	validation_0-mlogloss:0.64257
# [256]	validation_0-mlogloss:0.64257
# [257]	validation_0-mlogloss:0.64257
# [258]	validation_0-mlogloss:0.64257
# [259]	validation_0-mlogloss:0.64257
# [260]	validation_0-mlogloss:0.64257
# [261]	validation_0-mlogloss:0.64257
# [262]	validation_0-mlogloss:0.64257
# [263]	validation_0-mlogloss:0.64257
# [264]	validation_0-mlogloss:0.64257
# [265]	validation_0-mlogloss:0.64257
# [266]	validation_0-mlogloss:0.64257
# [267]	validation_0-mlogloss:0.64257
# [268]	validation_0-mlogloss:0.64257
# [269]	validation_0-mlogloss:0.64257
# [270]	validation_0-mlogloss:0.64257
# [271]	validation_0-mlogloss:0.64257
# [272]	validation_0-mlogloss:0.64257
# [273]	validation_0-mlogloss:0.64257
# [274]	validation_0-mlogloss:0.64257
# [275]	validation_0-mlogloss:0.64257
# [276]	validation_0-mlogloss:0.64257
# [277]	validation_0-mlogloss:0.64257
# [278]	validation_0-mlogloss:0.64257
# [279]	validation_0-mlogloss:0.64257
# [280]	validation_0-mlogloss:0.64257
# [281]	validation_0-mlogloss:0.64257
# [282]	validation_0-mlogloss:0.64257
# [283]	validation_0-mlogloss:0.64257
# [284]	validation_0-mlogloss:0.64257
# [285]	validation_0-mlogloss:0.64257
# [286]	validation_0-mlogloss:0.64257
# [287]	validation_0-mlogloss:0.64257
# [288]	validation_0-mlogloss:0.64257
# [289]	validation_0-mlogloss:0.64257
# [290]	validation_0-mlogloss:0.64257
# [291]	validation_0-mlogloss:0.64257
# [292]	validation_0-mlogloss:0.64257
# [293]	validation_0-mlogloss:0.64257
# [294]	validation_0-mlogloss:0.64257
# [295]	validation_0-mlogloss:0.64257
# [296]	validation_0-mlogloss:0.64257
# [297]	validation_0-mlogloss:0.64257
# [298]	validation_0-mlogloss:0.64257
# [299]	validation_0-mlogloss:0.64257
# [300]	validation_0-mlogloss:0.64257
# [301]	validation_0-mlogloss:0.64257
# [302]	validation_0-mlogloss:0.64257
# [303]	validation_0-mlogloss:0.64257
# [304]	validation_0-mlogloss:0.64257
# [305]	validation_0-mlogloss:0.64257
# [306]	validation_0-mlogloss:0.64257
# [307]	validation_0-mlogloss:0.64257
# [308]	validation_0-mlogloss:0.64257
# [309]	validation_0-mlogloss:0.64257
# [310]	validation_0-mlogloss:0.64257
# [311]	validation_0-mlogloss:0.64257
# [312]	validation_0-mlogloss:0.64257
# [313]	validation_0-mlogloss:0.64257
# [314]	validation_0-mlogloss:0.64257
# [315]	validation_0-mlogloss:0.64257
# [316]	validation_0-mlogloss:0.64257
# [317]	validation_0-mlogloss:0.64257
# [318]	validation_0-mlogloss:0.64257
# [319]	validation_0-mlogloss:0.64257
# [320]	validation_0-mlogloss:0.64257
# [321]	validation_0-mlogloss:0.64257
# [322]	validation_0-mlogloss:0.64257
# [323]	validation_0-mlogloss:0.64257
# [324]	validation_0-mlogloss:0.64257
# [325]	validation_0-mlogloss:0.64257
# [326]	validation_0-mlogloss:0.64257
# [327]	validation_0-mlogloss:0.64257
# [328]	validation_0-mlogloss:0.64257
# [329]	validation_0-mlogloss:0.64257
# [330]	validation_0-mlogloss:0.64257
# [331]	validation_0-mlogloss:0.64257
# [332]	validation_0-mlogloss:0.64257
# [333]	validation_0-mlogloss:0.64257
# [334]	validation_0-mlogloss:0.64257
# [335]	validation_0-mlogloss:0.64257
# [336]	validation_0-mlogloss:0.64257
# [337]	validation_0-mlogloss:0.64257
# [338]	validation_0-mlogloss:0.64257
# [339]	validation_0-mlogloss:0.64257
# [340]	validation_0-mlogloss:0.64257
# [341]	validation_0-mlogloss:0.64257
# [342]	validation_0-mlogloss:0.64257
# [343]	validation_0-mlogloss:0.64257
# [344]	validation_0-mlogloss:0.64257
# [345]	validation_0-mlogloss:0.64257
# [346]	validation_0-mlogloss:0.64257
# [347]	validation_0-mlogloss:0.64257
# [348]	validation_0-mlogloss:0.64257
# [349]	validation_0-mlogloss:0.64257
# [350]	validation_0-mlogloss:0.64257
# [351]	validation_0-mlogloss:0.64257
# [352]	validation_0-mlogloss:0.64257
# [353]	validation_0-mlogloss:0.64257
# [354]	validation_0-mlogloss:0.64257
# [355]	validation_0-mlogloss:0.64257
# [356]	validation_0-mlogloss:0.64257
# [357]	validation_0-mlogloss:0.64257
# [358]	validation_0-mlogloss:0.64257
# [359]	validation_0-mlogloss:0.64257
# [360]	validation_0-mlogloss:0.64257
# [361]	validation_0-mlogloss:0.64257
# [362]	validation_0-mlogloss:0.64257
# [363]	validation_0-mlogloss:0.64257
# [364]	validation_0-mlogloss:0.64257
# [365]	validation_0-mlogloss:0.64257
# [366]	validation_0-mlogloss:0.64257
# [367]	validation_0-mlogloss:0.64257
# [368]	validation_0-mlogloss:0.64257
# [369]	validation_0-mlogloss:0.64257
# [370]	validation_0-mlogloss:0.64257
# [371]	validation_0-mlogloss:0.64257
# [372]	validation_0-mlogloss:0.64257
# [373]	validation_0-mlogloss:0.64257
# [374]	validation_0-mlogloss:0.64257
# [375]	validation_0-mlogloss:0.64257
# [376]	validation_0-mlogloss:0.64257
# [377]	validation_0-mlogloss:0.64257
# [378]	validation_0-mlogloss:0.64257
# [379]	validation_0-mlogloss:0.64257
# [380]	validation_0-mlogloss:0.64257
# [381]	validation_0-mlogloss:0.64257
# [382]	validation_0-mlogloss:0.64257
# [383]	validation_0-mlogloss:0.64257
# [384]	validation_0-mlogloss:0.64257
# [385]	validation_0-mlogloss:0.64257
# [386]	validation_0-mlogloss:0.64257
# [387]	validation_0-mlogloss:0.64257
# [388]	validation_0-mlogloss:0.64257
# [389]	validation_0-mlogloss:0.64257
# [390]	validation_0-mlogloss:0.64257
# [391]	validation_0-mlogloss:0.64257
# [392]	validation_0-mlogloss:0.64257
# [393]	validation_0-mlogloss:0.64257
# [394]	validation_0-mlogloss:0.64257
# [395]	validation_0-mlogloss:0.64257
# [396]	validation_0-mlogloss:0.64257
# [397]	validation_0-mlogloss:0.64257
# [398]	validation_0-mlogloss:0.64257
# [399]	validation_0-mlogloss:0.64257
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9448531875640296, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='mlogloss', feature_types=None, feature_weights=None,
#               gamma=4.260249158096812, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1436348834661225,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=7, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=400, n_jobs=None, num_class=6, ...)

# %%
y_severity_pred_xgb = xgb_severity.predict(X_test)

# Evaluate
print(f"\nXGBoost Severity Prediction Accuracy: {accuracy_score(y_severity_test, y_severity_pred_xgb):.4f}")
print("\nClassification Report:")
print(classification_report(y_severity_test, y_severity_pred_xgb))
# Out:
# XGBoost Severity Prediction Accuracy: 0.8203
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90    155143
#            1       0.00      0.00      0.00         5
#            2       0.00      0.00      0.00     18264
#            3       0.00      0.00      0.00      1724
#            4       0.00      0.00      0.00       965
#            5       0.00      0.00      0.00     13024
#
#     accuracy                           0.82    189125
#    macro avg       0.14      0.17      0.15    189125
# weighted avg       0.67      0.82      0.74    189125
# c:\Users\ALOK\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ALOK\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\ALOK\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import matplotlib.pyplot as plt
import xgboost as xgb

plt.figure(figsize=(8, 6))

xgb.plot_importance(
    xgb_severity,
    max_num_features=13
)

plt.title('XGBoost Feature Importance - Severity Prediction')
plt.tight_layout()
plt.savefig('xgboost_feature_importance.png', dpi=300, bbox_inches='tight')
plt.show()
